# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Reading given data

# %%
data = pd.read_csv('raw_data_modified.csv', skipinitialspace=True)
data.head()
# Out:
#      Location State Senate Majority Political Affiliation  \
# 0     Alabama                                  Republican
# 1      Alaska                                  Republican
# 2     Arizona                                  Republican
# 3    Arkansas                                  Republican
# 4  California                                    Democrat
#
#   State House Majority Political Affiliation  Barbie vs Oppenheimer
# 0                                 Republican                     -6
# 1                                 Republican                      4
# 2                                 Republican                     -2
# 3                                 Republican                    -12
# 4                                   Democrat                      6

# %% [markdown]
# #### Barbie vs. Oppenheimer Data Analysis and Graph

# %%
data['pos'] = data['Barbie vs Oppenheimer'] > 0
data.plot(
    x='Location',
    y='Barbie vs Oppenheimer',
    kind='bar',
    figsize=(12, 6),
    title="Barbie vs. Oppenheimer by State",
    xlabel="State",
    ylabel="Rating",
    color=data.pos.map({True: "#1A262F", False: "pink"}))
# Out:
# <AxesSubplot:title={'center':'Barbie vs. Oppenheimer by State'}, xlabel='State', ylabel='Rating'>

# %% [markdown]
# #### State House Majority Political Affiliation

# %%
data['State House Majority Political Affiliation'].value_counts().plot(
    kind='pie',
    colors=["#d30b0d", "#013364", "#cbcaca"])
# Out:
# <AxesSubplot:ylabel='State House Majority Political Affiliation'>

# %% [markdown]
# #### State Senate Majority Political Affiliation

# %%
data['State Senate Majority Political Affiliation'].value_counts().plot(
    kind='pie',
    colors=["#d30b0d", "#013364"])
# Out:
# <AxesSubplot:ylabel='State Senate Majority Political Affiliation'>
