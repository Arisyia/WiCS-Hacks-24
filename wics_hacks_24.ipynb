# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Reading given data

# %%
data = pd.read_csv('raw_data_modified.csv', skipinitialspace=True)
data.head()
# Out:
#      Location State Senate Majority Political Affiliation  \
# 0     Alabama                                  Republican
# 1      Alaska                                  Republican
# 2     Arizona                                  Republican
# 3    Arkansas                                  Republican
# 4  California                                    Democrat
#
#   State House Majority Political Affiliation  Barbie vs Oppenheimer
# 0                                 Republican                     -6
# 1                                 Republican                      4
# 2                                 Republican                     -2
# 3                                 Republican                    -12
# 4                                   Democrat                      6

# %%
data_temp = data.groupby(["State Senate Majority Political Affiliation", "State House Majority Political Affiliation"]).size()
data_temp = data_temp.unstack()
data.plot(kind="bar", figsize=(12, 6))
# Out:
# <AxesSubplot:>

# %%
data.plot(x='Location', y='Barbie vs Oppenheimer', kind='bar',figsize=(12, 6),
    title="Barbie vs. Oppenheimer by State",
    xlabel="State",
    ylabel="Rating")
# Out:
# <AxesSubplot:title={'center':'Barbie vs. Oppenheimer by State'}, xlabel='State', ylabel='Rating'>
